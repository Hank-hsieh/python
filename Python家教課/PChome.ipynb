# %%
import requests

# %%
url = "https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%E5%A4%96%E6%8E%A5%E7%A1%AC%E7%A2%9F&page=1&sort=sale/dc"
url
# Out:
# 'https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=%E5%A4%96%E6%8E%A5%E7%A1%AC%E7%A2%9F&page=1&sort=sale/dc'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
print(dir(res))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
res.status_code
# Out:
# 200

# %%
res.request
# Out:
# <PreparedRequest [GET]>

# %%
res.request.method
# Out:
# 'GET'

# %%
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.21.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'QTime': 113,
#  'totalRows': 6971,
#  'totalPage': 100,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': '外接硬碟',
#  'subq': '',
#  'token': ['外接', '外', '接', '硬碟', '硬', '碟'],
#  'prods': [{'Id': 'DRAM07-A9009GEZ6',
#    'cateId': 'DRAM07',
#    'picS': '/items/DRAM07A9009GEZ6/000002_1555912260.jpg',
#    'picB': '/items/DRAM07A9009GEZ6/000001_1564625388.jpg',
#    'name': 'Seagate 新黑鑽 8TB USB3.0 3.5吋外接硬碟',
#    'describe': '▼愛別講理 送禮吧！▼Seagate 新黑鑽 8TB USB3.0 3.5吋外接硬碟\\r\\n《盛大開跑★禮享推薦》 \r\n開始：０８／０１（四）１１：００\r\n結束：０８／０９（五）１１：００\r\n網路價$5299．限時價↘$4899\r\n\r\n★usb3.0高速傳輸\r\n★菱格紋外殼，高雅時尚\r\n★霧面靚黑，不沾灰 指紋\r\n★內建電源管理功能，環保節能\r\n★隨插即用 免安裝 \r\n★原廠三年保固\r\n\r\n\r\n讓館長跟你說什麼叫cp值！不再哀嚎不夠存！\r\n\r\n* 儲存界赫赫有名的世界大廠 seagate！ \r\n* 直立設計 放在桌上不占空間\r\n* 看膩黑色硬碟 菱格紋94走在時尚尖端\r\n* 內附電源轉接器 出國在外也可以恣意的存取\r\n* 隨插即用 無腦儲存超easy！\r\n\r\n最後 館長誠心建議 背多分不如多備幾份！\r\n還不快點買起來！！！\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑8月儲值優惠活動，請點我\r\n\r\n8月銀行優惠 限量需登錄\r\n↑銀行刷卡活動詳情請點圖片了解',
#    'price': 4899,
#    'originPrice': 4899,
# ...

# %%
res.json().keys()
# Out:
# dict_keys(['QTime', 'totalRows', 'totalPage', 'range', 'cateName', 'q', 'subq', 'token', 'prods'])

# %%
res.json()["prods"]
# Out:
# [{'Id': 'DRAM07-A9009GEZ6',
#   'cateId': 'DRAM07',
#   'picS': '/items/DRAM07A9009GEZ6/000002_1555912260.jpg',
#   'picB': '/items/DRAM07A9009GEZ6/000001_1564625388.jpg',
#   'name': 'Seagate 新黑鑽 8TB USB3.0 3.5吋外接硬碟',
#   'describe': '▼愛別講理 送禮吧！▼Seagate 新黑鑽 8TB USB3.0 3.5吋外接硬碟\\r\\n《盛大開跑★禮享推薦》 \r\n開始：０８／０１（四）１１：００\r\n結束：０８／０９（五）１１：００\r\n網路價$5299．限時價↘$4899\r\n\r\n★usb3.0高速傳輸\r\n★菱格紋外殼，高雅時尚\r\n★霧面靚黑，不沾灰 指紋\r\n★內建電源管理功能，環保節能\r\n★隨插即用 免安裝 \r\n★原廠三年保固\r\n\r\n\r\n讓館長跟你說什麼叫cp值！不再哀嚎不夠存！\r\n\r\n* 儲存界赫赫有名的世界大廠 seagate！ \r\n* 直立設計 放在桌上不占空間\r\n* 看膩黑色硬碟 菱格紋94走在時尚尖端\r\n* 內附電源轉接器 出國在外也可以恣意的存取\r\n* 隨插即用 無腦儲存超easy！\r\n\r\n最後 館長誠心建議 背多分不如多備幾份！\r\n還不快點買起來！！！\r\n\r\n\r\n館長小叮嚀：儲值購買最划算～\r\n↑8月儲值優惠活動，請點我\r\n\r\n8月銀行優惠 限量需登錄\r\n↑銀行刷卡活動詳情請點圖片了解',
#   'price': 4899,
#   'originPrice': 4899,
#   'author': '',
#   'brand': '',
#   'publishDate': '',
#   'sellerId': '',
#   'isPChome': 1,
#   'isNC17': 0,
#   'couponActid': [],
#   'BU': 'ec'},
#  {'Id': 'DRAA6H-A9007L6VO',
#   'cateId': 'DRAA6H',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(res.json()["prods"])
df
# Out:
#     BU                Id author brand  cateId couponActid  \
# 0   ec  DRAM07-A9009GEZ6               DRAM07          []
# 1   ec  DRAA6H-A9007L6VO               DRAA6H          []
# 2   ec  DRAB2M-A9008265A               DRAB2M          []
# 3   ec  DRAB5S-A9008UCUI               DRAB5S          []
# 4   ec  DRAH6Y-A9009FQYM               DRAH87          []
# 5   ec  DRAB2U-A9007SZUQ               DRAB4C          []
# 6   ec  DRAA6H-A9007O6DG               DRAA6H          []
# 7   ec  DRAB0S-A9007TU02               DRAB0S          []
# 8   ec  DRAA1V-A9008J35Y               DRAA1V          []
# 9   ec  DRAB19-A76594300               DRAB4G          []
# 10  ec  DRAB0S-A90079LH7               DRAB0S          []
# 11  ec  DRAH6Y-A9009FQXX               DRAH87          []
# 12  ec  DRAB2U-A9005LMZ1               DRAB2U          []
# 13  ec  DRAA6H-A90094Y0D               DRAA6H          []
# 14  ec  DRAB1X-A65586572               DRAB31          []
# ...
